# %% [markdown]
# ![image.png](attachment:e186016e-3fe2-4f5b-9cef-d9290cc46601.png)
# ![image.png](attachment:0d4c9ee8-578b-4080-b18a-22b51c9b31f3.png)
# ![image.png](attachment:6661eef1-7639-4367-9a78-ce933274225b.png)
# ![image.png](attachment:d26ed350-c29d-4cbe-b6e4-7bbefaff3347.png)
# ![image.png](attachment:bc69f6f9-3108-4f33-9f89-3e03c684febf.png)

# %% [markdown]
# # Final Result :
# ![image.png](attachment:e254a047-14e4-4bb9-9571-4e6c8ce43245.png)
#
# ![image.png](attachment:787ac22f-b914-4d00-aa3f-3d36322fe4da.png)
