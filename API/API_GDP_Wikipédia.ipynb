# %%
import numpy as np
import pandas as pd

# You can also use this section to suppress warnings generated by your code:
def warn(*args, **kwargs):
    pass
import warnings
warnings.warn = warn
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Exercise
# Extract the required GDP data from the given URL using Web Scraping.

# %%
URL="https://web.archive.org/web/20230902185326/https://en.wikipedia.org/wiki/List_of_countries_by_GDP_%28nominal%29"

# %%
# Extract tables from webpage using Pandas. Retain table number 3 as the required dataframe.
tables = pd.read_html(URL)
df = tables[3]
print(df[3].head())
# Replace the column headers with column numbers
df.columns = range(df.shape[1])

# Retain columns with index 0 and 2 (name of country and value of GDP quoted by IMF)
df2 = df[['Country/Territory','IMF']]
# Retain the Rows with index 1 to 10, indicating the top 10 economies of the world.
df_final=df2.loc[0:11, :]
# Assign column names as "Country" and "GDP (Million USD)"
df_final.columns = ["Country","GDP (Million USD)"]
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python313\Lib\urllib\request.py:1319, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1318 try:
# -> 1319     h.request(req.get_method(), req.selector, req.data, headers,
#    1320               encode_chunked=req.has_header('Transfer-encoding'))
#    1321 except OSError as err: # timeout error
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\http\client.py:1338, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1337 """Send a complete request to the server."""
# -> 1338 self._send_request(method, url, body, headers, encode_chunked)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\http\client.py:1384, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
# ...

# %%
# Change the data type of the 'GDP (Million USD)' column to integer. Use astype() method.
df_final['GDP (Million USD)'] = df_final['GDP (Million USD)'].astype(int)
# Convert the GDP value in Million USD to Billion USD
df_final[['GDP (Million USD)']] = df_final[['GDP (Million USD)']]/1000
# Use numpy.round() method to round the value to 2 decimal places.
df_final[['GDP (Million USD']] = np.round(df_final[['GDP (Million USD']],2)
# Rename the column header from 'GDP (Million USD)' to 'GDP (Billion USD)'
df_final.rename(columns = {'GDP (Million USD)' : 'GDP (Billion USD)'})

# %%
# Load the DataFrame to the CSV file named "Largest_economies.csv"
df_final.to_csv("Largest_economies.csv")
